# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.getcwd()
# Out:
# '/Users/pranav/AIML/CV/MyProjects/HumanDetection_RaspberryPi/yolo'

# %%
# os.chdir('/content/drive/MyDrive/gdrive/HumanDetection')

# %%
os.listdir()
# Out:
# ['PEOPLE WALKING AROUND.mp4',
#  'HumanDetection_using_raspberryPi_video.ipynb',
#  '.DS_Store',
#  'humanDetection.mp4',
#  'HumanDetection',
#  'human_detection_dataset.zip',
#  '.ipynb_checkpoints']

# %%
# zip_path = '/content/drive/MyDrive/gdrive/HumanDetection/human_detection_dataset.zip'

# %%
# !cp {'zip_path'}
# Out:
# cp: missing destination file operand after 'zip_path'
# Try 'cp --help' for more information.

# %%
# #uniziping
# !unzip -q '/content/drive/MyDrive/gdrive/human_detection_dataset.zip'

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
# model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 18.4MB/s]

# %%
# results = model.train(data='data.yaml', epochs=30)
# Out:
# Ultralytics YOLOv8.0.154 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# results = model.val()
# Out:
# Ultralytics YOLOv8.0.154 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
# val: Scanning /content/drive/MyDrive/gdrive/HumanDetection/valid/labels.cache... 92 images, 90 backgrounds, 0 corrupt: 100%|██████████| 92/92 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:03<00:00,  1.88it/s]
#                    all         92          9      0.827      0.667      0.713      0.423
# Speed: 2.8ms preprocess, 14.6ms inference, 0.0ms loss, 2.6ms postprocess per image
# Results saved to runs/detect/val

# %%
model = YOLO('/Users/pranav/AIML/CV/MyProjects/HumanDetection_RaspberryPi/yolo/HumanDetection/runs/detect/train/weights/best.pt')

# %%
vdo_path = '/Users/pranav/AIML/CV/MyProjects/HumanDetection_RaspberryPi/yolo/humanDetection.mp4'

# %%
vdo_path = '/Users/pranav/AIML/CV/MyProjects/HumanDetection_RaspberryPi/yolo/PEOPLE WALKING AROUND.mp4'

# %%
vdo_path
# Out:
# '/Users/pranav/AIML/CV/MyProjects/HumanDetection_RaspberryPi/yolo/humanDetection.mp4'

# %%
import cv2
from ultralytics import YOLO
from ultralytics.yolo.utils.plotting import Annotator
# Out:
# WARNING ⚠️ 'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.
# WARNING ⚠️ 'ultralytics.yolo.utils' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.utils' instead.
# Note this warning may be related to loading older models. You can update your model to current structure with:
#     import torch
#     ckpt = torch.load("model.pt")  # applies to both official and custom models
#     torch.save(ckpt, "updated-model.pt")

# %%
cap = cv2.VideoCapture(vdo_path)
while cap.isOpened():
    success, img = cap.read()
    if success:
        resized_img = cv2.resize(img, (640, 640))
        results = model(resized_img, conf=0.25)
        annotated_frame = results[0].plot()
        cv2.imshow("YOLOv8 Inference", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break

    else:
        # Break the loop if the end of the video is reached
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x640 3 Humanss, 97.2ms
# Speed: 2.0ms preprocess, 97.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 Humanss, 94.5ms
# Speed: 1.5ms preprocess, 94.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 Humanss, 86.7ms
# Speed: 1.4ms preprocess, 86.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 Humanss, 103.9ms
# Speed: 2.3ms preprocess, 103.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 Humanss, 94.0ms
# Speed: 1.3ms preprocess, 94.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 Humanss, 91.8ms
# Speed: 1.3ms preprocess, 91.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 Humanss, 94.5ms
# Speed: 1.7ms preprocess, 94.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 3 Humanss, 97.6ms
# ...

# %%
cap.release()
cv2.destroyAllWindows()
